# %%
# !pip install ultralytics
# !pip install roboflow

# %% [markdown]
# # Get datasets

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="aHTuNw5oGE8wOGtyWIfN")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
dataset.location
# Out:
# 'c:\\Users\\Afonso\\Downloads\\football_analysis\\training\\football-players-detection-1'

# %%
import shutil 

shutil.move('football-players-detection-1/train', 'football-players-detection-1/football-players-detection-1/train') # move the train folder to the correct location
shutil.move('football-players-detection-1/valid', 'football-players-detection-1/football-players-detection-1/valid') # move the valid folder to the correct location
shutil.move('football-players-detection-1/test', 'football-players-detection-1/football-players-detection-1/test') # move the test folder to the correct location
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\Afonso\AppData\Local\Programs\Python\Python312\Lib\shutil.py:847, in move(src, dst, copy_function)
#     846 try:
# --> 847     os.rename(src, real_dst)
#     848 except OSError:
#
# FileNotFoundError: [WinError 2] O sistema não conseguiu localizar o ficheiro especificado: 'football-players-detection-1/train' -> 'football-players-detection-1/football-players-detection-1/train\\train'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 3
#       1 import shutil
# ----> 3 shutil.move('football-players-detection-1/train', 'football-players-detection-1/football-players-detection-1/train') # move the train folder to the correct location
# ...

# %% [markdown]
# # Training

# %%
import torch 
torch.cuda.empty_cache()
amp=True

# !yolo task=detect mode=train model=yolov5xu.pt data={dataset.location}/data.yaml epochs=100 batch=8 imgsz=640
# Out:
# Ultralytics 8.3.15 🚀 Python-3.12.5 torch-2.5.0+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# train: Scanning C:\Users\Afonso\Downloads\football_analysis\training\football-players-detection-1\football-players-detection-1\train\labels.cache... 612 images, 0 backgrounds, 0 corrupt: 100%|██████████| 612/612 [00:00<?, ?it/s]
# train: Scanning C:\Users\Afonso\Downloads\football_analysis\training\football-players-detection-1\football-players-detection-1\train\labels.cache... 612 images, 0 backgrounds, 0 corrupt: 100%|██████████| 612/612 [00:00<?, ?it/s]
#
# val: Scanning C:\Users\Afonso\Downloads\football_analysis\training\football-players-detection-1\football-players-detection-1\valid\labels.cache... 38 images, 0 backgrounds, 0 corrupt: 100%|██████████| 38/38 [00:00<?, ?it/s]
# ...
